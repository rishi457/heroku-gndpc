# %% [markdown]
# # importing libraries

# %%
from pandas import *
from numpy import *
from matplotlib.pyplot import *
import seaborn as s
from sklearn.model_selection import train_test_split as t, cross_val_score as cross
import pickle as p
from sklearn.neighbors import KNeighborsClassifier as knc
from sklearn.metrics import classification_report as c
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # reading csv file

# %%
df = read_csv('train.csv')

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# # list of columns in the dataframe

# %%
0.200723	0.020573	-0.006606	0.017444	0.021998	0.014772	0.044435	0.000853	-0.030302	0.004399	...	0.148858	0.165818	0.917046	0.022986	0.038711	0.021859	0.023611	-0.030411	0.018785	1.000000
21 rows × 21 columns
# Out:
#   File "<ipython-input-141-5c41411ead09>", line 1
#     0.200723	0.020573	-0.006606	0.017444	0.021998	0.014772	0.044435	0.000853	-0.030302	0.004399	...	0.148858	0.165818	0.917046	0.022986	0.038711	0.021859	0.023611	-0.030411	0.018785	1.000000
#             	^
# SyntaxError: invalid syntax

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %% [markdown]
# # training the model

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-175-b5059f44c98a> in <module>
# ----> 1 c(test_y, lr.predict(test_x))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     307             Predicted class label per sample.
#     308         """
# --> 309         scores = self.decision_function(X)
#     310         if len(scores.shape) == 1:
#     311             indices = (scores > 0).astype(int)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     286         n_features = self.coef_.shape[1]
#     287         if X.shape[1] != n_features:
# --> 288             raise ValueError("X has %d features per sample; expecting %d"
#     289                              % (X.shape[1], n_features))
#     290
#
# ...

# %%
x = df[[ 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
       'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       'touch_screen', 'wifi']]
y = df[['price_range' ]]

# %%
df.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
train_x, test_x, train_y, test_y = t(x, y, test_size = 0.3)

# %%
train_x

# %%
df.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
x.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
0
# Out:
# C:\Users\abc\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=6)

# %%
# Out:
# pandas.core.frame.DataFrame

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       152
#            1       0.89      0.88      0.89       144
#            2       0.90      0.83      0.86       155
#            3       0.91      0.93      0.92       149
#
#     accuracy                           0.91       600
#    macro avg       0.91      0.91      0.91       600
# weighted avg       0.91      0.91      0.91       600

# %%
x.corr()
# Out:
#                battery_power      blue        fc  int_memory  mobile_wt  \
# battery_power       1.000000  0.011252  0.033334   -0.004004   0.001844
# blue                0.011252  1.000000  0.003593    0.041177  -0.008605
# fc                  0.033334  0.003593  1.000000   -0.029133   0.023618
# int_memory         -0.004004  0.041177 -0.029133    1.000000  -0.034214
# mobile_wt           0.001844 -0.008605  0.023618   -0.034214   1.000000
# pc                  0.031441 -0.009952  0.644595   -0.033273   0.018844
# px_height           0.014901 -0.006872 -0.009990    0.010441   0.000939
# px_width           -0.008402 -0.041533 -0.005176   -0.008335   0.000090
# ram                -0.000653  0.026351  0.015099    0.032813  -0.002581
# sc_h               -0.029959 -0.002952 -0.011014    0.037771  -0.033855
# sc_w               -0.021421  0.000613 -0.012373    0.011731  -0.020761
# talk_time           0.052510  0.013934 -0.006829   -0.002790   0.006209
#
# ...

# %% [markdown]
# # logestic regression

# %%
lr = LogisticRegression()

# %%
lr.fit(train_x, train_y)
# Out:
# C:\Users\abc\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\abc\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.predict(test_x)
# Out:
# array([2, 0, 1, 2, 2, 1, 3, 2, 1, 0, 2, 2, 0, 3, 3, 3, 3, 2, 2, 2, 1, 3,
#        3, 3, 0, 1, 3, 0, 0, 3, 1, 2, 1, 3, 1, 3, 3, 0, 1, 1, 1, 3, 3, 0,
#        3, 0, 3, 3, 3, 1, 1, 2, 2, 0, 2, 2, 3, 0, 2, 2, 1, 2, 1, 3, 2, 3,
#        3, 3, 2, 0, 3, 2, 1, 0, 3, 2, 2, 0, 2, 0, 2, 3, 1, 3, 2, 3, 1, 0,
#        3, 0, 1, 3, 0, 1, 0, 1, 0, 3, 3, 1, 3, 2, 0, 0, 3, 2, 0, 3, 2, 3,
#        2, 1, 2, 1, 1, 3, 1, 1, 0, 0, 2, 2, 1, 2, 0, 3, 3, 2, 0, 0, 3, 3,
#        0, 3, 0, 3, 0, 2, 3, 2, 3, 1, 2, 3, 0, 2, 0, 2, 3, 2, 3, 1, 1, 0,
#        0, 1, 2, 0, 2, 3, 1, 3, 1, 0, 1, 3, 3, 2, 1, 2, 0, 0, 3, 0, 0, 0,
#        3, 1, 0, 2, 1, 0, 0, 2, 2, 1, 2, 0, 0, 1, 3, 1, 2, 0, 3, 1, 2, 0,
#        2, 0, 0, 1, 0, 1, 0, 1, 3, 3, 2, 0, 1, 3, 3, 0, 1, 3, 2, 2, 2, 2,
#        3, 3, 2, 2, 0, 2, 1, 3, 0, 2, 0, 1, 1, 0, 3, 1, 3, 2, 2, 3, 1, 0,
#        0, 3, 3, 2, 1, 0, 1, 0, 2, 1, 0, 2, 3, 3, 0, 3, 1, 1, 2, 1, 3, 1,
#        3, 1, 2, 3, 0, 0, 3, 1, 0, 0, 0, 1, 2, 2, 0, 2, 0, 0, 3, 0, 3, 0,
# ...

# %%
l.fit(train_x, train_y)
# Out:
# C:\Users\abc\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\abc\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # finding k nearest neighbours

# %%
ks = list(range(2, 500, 2))

# %%
cvScores = []

# %%
c(lr.predict(test_x), finalKNN.predict(test_x))
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.75      0.85      0.80       131\n           1       0.52      0.59      0.56       135\n           2       0.46      0.46      0.46       146\n           3       0.80      0.65      0.72       188\n\n    accuracy                           0.64       600\n   macro avg       0.63      0.64      0.63       600\nweighted avg       0.64      0.64      0.64       600\n'

# %%
print(c(finalKNN.predict(test_x), lr.predict(test_x) ))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81       172
#            1       0.61      0.61      0.61       148
#            2       0.46      0.46      0.46       126
#            3       0.64      0.70      0.67       154
#
#     accuracy                           0.65       600
#    macro avg       0.64      0.64      0.64       600
# weighted avg       0.65      0.65      0.65       600

# %%
cvScores.index([0.9339999999999999])
# Out:
# 261

# %%
bar(lr.predict(test_x), loadedModel.predict(test_x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-db6d8721c720> in <module>
# ----> 1 bar(l.predict(test_x), loadedModel.predict(test_x))
#
# NameError: name 'l' is not defined

# %%
plot(l.predict(test_x))

# %%
max(cvScores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-f11dbfa628eb> in <module>
# ----> 1 max(cvScores)
#
# ValueError: max() arg is an empty sequence

# %%
x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
print(c(finalKNN.predict(test_x), lr.predict(test_x)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-c4c3da35fd0b> in <module>
# ----> 1 print(c(finalKNN.predict(test_x), lr.predict(test_x)))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_classification.py in predict(self, X)
#     195         X = check_array(X, accept_sparse='csr')
#     196
# --> 197         neigh_dist, neigh_ind = self.kneighbors(X)
#     198         classes_ = self.classes_
#     199         _y = self._y
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     703                 kwds = self.effective_metric_params_
#     704
# --> 705             chunked_results = list(pairwise_distances_chunked(
#     706                 X, self._fit_X, reduce_func=reduce_func,
# ...

# %%
from sklearn.metrics import classification_report as c

# %%
cvScores.index(max(cvScores))
# Out:
# 12

# %%
for k in ks:
    testKNN = knc(n_neighbors=k)
    score = cross(testKNN, x, y, cv=5, scoring='accuracy').mean()
    cvScores.append(score)
# Out:
# C:\Users\abc\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\abc\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\abc\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %% [markdown]
# # as required neighbors come to be 12, so we will store it in finalKNN by applying function k neighbors classifier which we had imported earlier and fit finalKNN in neighbors

# %%
l = list(lr.predict(test_x))

# %%
plot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-e538c60ff8d7> in <module>
# ----> 1 plot(l,df['price_range'] )
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
# ...

# %%
finalKNN = knc(n_neighbors=261)
finalKNN.fit(x, y)
# Out:
# C:\Users\abc\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=261)

# %%
p.dump(finalKNN, open('KNN Model7.pkl', 'wb'))
p.dump(lr, open('KNN Model6.pkl', 'wb'))

# %% [markdown]
# # now we created a var. called loadedModel which

# %%
loadedModel = p.load(open('KNN Model7.pkl', 'rb'))
loadedModel1 = p.load(open('KNN Model6.pkl', 'rb'))
loadedModel1.fit(train_x, train_y)
# Out:
# C:\Users\abc\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\abc\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
loadedModel1.predict([[1, 0, 0, 0, 0]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ce99af2e8744> in <module>
# ----> 1 loadedModel1.predict([[1, 0, 0, 0, 0]])
#
# NameError: name 'loadedModel1' is not defined

# %%
loadedModel.predict([[510, 1, 2, 1, 5]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-381d2625edbf> in <module>
# ----> 1 loadedModel.predict([[510, 1, 2, 1, 5]])
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_classification.py in predict(self, X)
#     195         X = check_array(X, accept_sparse='csr')
#     196
# --> 197         neigh_dist, neigh_ind = self.kneighbors(X)
#     198         classes_ = self.classes_
#     199         _y = self._y
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     703                 kwds = self.effective_metric_params_
#     704
# --> 705             chunked_results = list(pairwise_distances_chunked(
#     706                 X, self._fit_X, reduce_func=reduce_func,
# ...

# %%
lr = LogisticRegression()

# %%
loaded
